# %%
import pandas as pd

# %%
data2_3=pd.read_excel('E:\泰迪\三届\B\附件2.xlsx',encoding='GBK')
data2_3.head()
# Out:
#    序号            企业名称     产品通用名称 产品形态  总氮百分比  P2O5百分比  K2O百分比 含氯情况  有机质百分比  \
# 0   1  武汉楚天艾科生物工程有限公司  有机-无机复混肥料   粒状   0.09     0.06    0.00   无氯     0.2
# 1   2   嘉施利（应城）化肥有限公司       复混肥料   粒状   0.17     0.17    0.07   低氯     0.0
# 2   3   嘉施利（应城）化肥有限公司       复混肥料   粒状   0.20     0.05    0.15   无氯     0.0
# 3   4   嘉施利（应城）化肥有限公司       复混肥料   粒状   0.26     0.08    0.10   中氯     0.0
# 4   5     湖北澳特尔化工有限公司       复混肥料   粒状   0.15     0.15    0.15   无氯     0.0
#
#               正式登记证号        发证日期      有效期 产品商品名称 适用作物  总无机养分百分比
# 0   鄂农肥（2009）准字0001号  2014-02-25  2019-02    NaN  NaN      0.15
# 1   鄂农肥（2009）准字0004号  2014-08-15  2019-08    NaN  NaN      0.41
# 2   鄂农肥（2009）准字0005号  2014-08-15  2019-08    NaN  NaN      0.40
# 3   鄂农肥（2009）准字0006号  2014-08-15  2019-08    NaN  NaN      0.44
# 4  鄂农肥（2009）准字00079号  2014-10-25  2019-10    NaN  NaN      0.45

# %%
data2_3_1=data2_3['总无机养分百分比'] = round((data2_3['总氮百分比']+data2_3['P2O5百分比']+data2_3['K2O百分比']),3)
data2_3_1.head()
# Out:
# 0    0.15
# 1    0.41
# 2    0.40
# 3    0.44
# 4    0.45
# dtype: float64

# %%
data2_3.head()
# Out:
#    序号            企业名称     产品通用名称 产品形态  总氮百分比  P2O5百分比  K2O百分比 含氯情况  有机质百分比  \
# 0   1  武汉楚天艾科生物工程有限公司  有机-无机复混肥料   粒状   0.09     0.06    0.00   无氯     0.2
# 1   2   嘉施利（应城）化肥有限公司       复混肥料   粒状   0.17     0.17    0.07   低氯     0.0
# 2   3   嘉施利（应城）化肥有限公司       复混肥料   粒状   0.20     0.05    0.15   无氯     0.0
# 3   4   嘉施利（应城）化肥有限公司       复混肥料   粒状   0.26     0.08    0.10   中氯     0.0
# 4   5     湖北澳特尔化工有限公司       复混肥料   粒状   0.15     0.15    0.15   无氯     0.0
#
#               正式登记证号        发证日期      有效期 产品商品名称 适用作物  总无机养分百分比
# 0   鄂农肥（2009）准字0001号  2014-02-25  2019-02    NaN  NaN      0.15
# 1   鄂农肥（2009）准字0004号  2014-08-15  2019-08    NaN  NaN      0.41
# 2   鄂农肥（2009）准字0005号  2014-08-15  2019-08    NaN  NaN      0.40
# 3   鄂农肥（2009）准字0006号  2014-08-15  2019-08    NaN  NaN      0.44
# 4  鄂农肥（2009）准字00079号  2014-10-25  2019-10    NaN  NaN      0.45

# %%
data2_4=data2_3[['总无机养分百分比']]

# %%
iris = data2_4
data_x=iris
data = pd.DataFrame(iris,columns=['总氮百分比','P2O5百分比','K2O百分比'])
data['总无机养分百分比']=iris
data.head()
# Out:
#    总氮百分比  P2O5百分比  K2O百分比  总无机养分百分比
# 0    NaN      NaN     NaN      0.15
# 1    NaN      NaN     NaN      0.41
# 2    NaN      NaN     NaN      0.40
# 3    NaN      NaN     NaN      0.44
# 4    NaN      NaN     NaN      0.45

# %%
data2_3.head(2)
# Out:
#    序号            企业名称     产品通用名称 产品形态  总氮百分比  P2O5百分比  K2O百分比 含氯情况  有机质百分比  \
# 0   1  武汉楚天艾科生物工程有限公司  有机-无机复混肥料   粒状   0.09     0.06    0.00   无氯     0.2
# 1   2   嘉施利（应城）化肥有限公司       复混肥料   粒状   0.17     0.17    0.07   低氯     0.0
#
#              正式登记证号        发证日期      有效期 产品商品名称 适用作物  总无机养分百分比
# 0  鄂农肥（2009）准字0001号  2014-02-25  2019-02    NaN  NaN      0.15
# 1  鄂农肥（2009）准字0004号  2014-08-15  2019-08    NaN  NaN      0.41

# %%
data2_3=data2_3[data2_3['产品通用名称'].isin(['复混肥料'])] 
data2_3
# Out:
#         序号                 企业名称 产品通用名称 产品形态   总氮百分比  P2O5百分比  K2O百分比 含氯情况  \
# 1        2        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.1700   0.1700  0.0700   低氯
# 2        3        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2000   0.0500  0.1500   无氯
# 3        4        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2600   0.0800  0.1000   中氯
# 4        5          湖北澳特尔化工有限公司   复混肥料   粒状  0.1500   0.1500  0.1500   无氯
# 5        6        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2000   0.0500  0.1100   无氯
# 6        7          湖北澳特尔化工有限公司   复混肥料   粒状  0.1400   0.1600  0.1500   无氯
# 7        8        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2400   0.1000  0.1400   中氯
# 8        9        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2600   0.1000  0.1500   中氯
# 9       10        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2500   0.0500  0.0500   中氯
# 10      11        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2000   0.0500  0.2000   无氯
# 11      12        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.3000   0.0000  0.0500   高氯
# 12      13        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.3000   0.0500  0.0000   中氯
# ...

# %%
# v_count = data2_3.groupby('总无机养分百分比')['总氮百分比'].count()

# %%
x1=data2_3[['总氮百分比','P2O5百分比']].iloc[:,:].values
from sklearn.cluster import KMeans
inertia=[]
for i in range(1,11):  
    km=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=100)
    km.fit(x1)
    inertia.append(km.inertia_)

# %%
import matplotlib.pyplot as plt
km = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 100)
y_means = km.fit_predict(x1)
plt.rcParams['font.sans-serif'] = ['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False #用来正常显示负号
plt.figure(1 , figsize = (12 , 6) )
plt.scatter(x1[y_means == 0, 0], x1[y_means == 0, 1], s = 200, c = 'salmon')
plt.scatter(x1[y_means == 1, 0], x1[y_means == 1, 1], s = 200, c = 'yellowgreen') 
plt.scatter(x1[y_means == 2, 0], x1[y_means == 2, 1], s = 200, c = 'cornflowerblue')
plt.scatter(x1[y_means == 3, 0], x1[y_means == 3, 1], s = 200, c = 'magenta')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 100, c = 'black' , label = 'centeroid')

plt.ylabel('P2O5百分比') , plt.xlabel('总氮百分比')
plt.legend()
plt.show()

# %%
x2=data2_3[['总氮百分比','K2O百分比']].iloc[:,:].values
from sklearn.cluster import KMeans
inertia=[]
for i in range(1,11):  
    km=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=100)
    km.fit(x2)
    inertia.append(km.inertia_)

# %%
plt.figure(1,figsize=(12,6))    
plt.plot(range(1,11),inertia)
plt.title('The Elbow Method',fontsize=20)
plt.xlabel('Number of Clusters')
plt.ylabel('inertia')
plt.show()

# %%
km = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 100)
y_means = km.fit_predict(x2)

plt.figure(1 , figsize = (12 , 6) )
plt.scatter(x2[y_means == 0, 0], x2[y_means == 0, 1], s = 200, c = 'salmon')
plt.scatter(x2[y_means == 1, 0], x2[y_means == 1, 1], s = 200, c = 'yellowgreen') 
plt.scatter(x2[y_means == 2, 0], x2[y_means == 2, 1], s = 200, c = 'cornflowerblue')
plt.scatter(x2[y_means == 3, 0], x2[y_means == 3, 1], s = 200, c = 'magenta')
plt.scatter(x2[y_means == 4, 0], x2[y_means == 4, 1], s = 200, c = 'LightSeaGreen')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 100, c = 'black',label = 'centeroid')

plt.ylabel('Spending Score (1-100)') , plt.xlabel('Annual Income (k$)')
plt.legend()
plt.show()

# %%
x3=data2_3[['总氮百分比' , 'P2O5百分比' ,'K2O百分比']].iloc[: , :].values
from sklearn.cluster import KMeans
inertia=[]
for i in range(1,11):  
    km=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    km.fit(x3)
    inertia.append(km.inertia_)

# %%
plt.figure(1,figsize=(12,6))    
plt.plot(range(1,11),inertia)
plt.title('The Elbow Method',fontsize=20)
plt.xlabel('Number of Clusters')
plt.ylabel('inertia')
plt.show()

# %%
algorithm = (KMeans(n_clusters = 4 ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 100  , algorithm='elkan') )
algorithm.fit(x3)
labels = algorithm.labels_
centroids = algorithm.cluster_centers_

# %%
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple --trusted-host pypi.tuna.tsinghua.edu.cn plotly --upgrade

# %%
# conda install https://pypi.tuna.tsinghua.edu.cn/simple plotly

# %%
# conda install https://pypi.tuna.tsinghua.edu.cn/simple plotly.graph_objects

# %%
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple plotly

# %%
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple "notebook>=5.3" "ipywidgets>=7.2"

# %%
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple jupyterlab "ipywidgets>=7.5"

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('fivethirtyeight')

from sklearn.cluster import KMeans
import plotly as py
import plotly.graph_objects as go

import warnings
import os
warnings.filterwarnings('ignore')

# %%
import plotly.graph_objects as go
data2_3['label'] =  labels
trace1 = go.Scatter3d(
    x= data2_3['总氮百分比'],
    y= data2_3['P2O5百分比'],
    z= data2_3['K2O百分比'],
    mode='markers',
     marker=dict(
        color = data2_3['label'], 
        size= 15,
        line=dict(
            color= data2_3['label'],
            width= 10
        ),
        opacity=0.8
     )
)
data = [trace1]
layout = go.Layout(
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0
#     )
    height=800,
    width=800,
    title= 'Clusters',
    scene = dict(
            xaxis = dict(title  = '总氮百分比'),
            yaxis = dict(title  = 'P2O5百分比'),
            zaxis = dict(title  = 'K2O百分比')
        )
)
fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
# Out:
# <div>                            <div id="4f680d93-af52-4e49-b801-33b7e9777b21" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f680d93-af52-4e49-b801-33b7e9777b21")) {                    Plotly.newPlot(                        "4f680d93-af52-4e49-b801-33b7e9777b21",                        [{"marker":{"color":[2,0,1,2,3,2,1,1,1,0,1,1,1,1,1,1,3,0,0,0,3,3,2,2,3,3,3,1,2,1,2,3,3,3,0,0,3,0,1,1,2,3,2,2,3,3,0,0,1,2,2,3,2,3,1,1,2,2,3,1,1,0,0,3,2,3,0,2,2,0,2,2,3,0,2,3,3,1,1,1,2,1,3,2,2,1,1,1,3,1,1,1,2,0,1,1,1,1,1,0,2,2,2,2,3,3,1,0,3,0,2,2,2,2,3,2,2,2,1,2,2,2,0,1,0,0,3,2,3,1,1,2,2,0,3,2,3,1,1,2,2,1,2,2,2,1,1,3,2,1,1,1,1,1,1,2,2,0,2,2,1,1,3,1,2,1,2,1,2,2,2,3,2,2,2,3,2,2,1,2,2,2,2,1,3,3,3,3,1,2,0,1,2,2,1,1,1,2,0,2,1,3,3,3,3,1,1,0,1,3,3,3,0,0,0,0,1,2,2,2,1,1,3,
# ...

# %%
data2_99=data2_3['label']
data2_99=data2_99.replace([0,1,2,3],['1','2','3','4'])
data2_3['label']=data2_99

# %%
data2_3=data2_3.rename(columns={'标签': '聚类标签'})
data2_3
# Out:
#         序号                 企业名称 产品通用名称 产品形态   总氮百分比  P2O5百分比  K2O百分比 含氯情况  \
# 1        2        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.1700   0.1700  0.0700   低氯
# 2        3        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2000   0.0500  0.1500   无氯
# 3        4        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2600   0.0800  0.1000   中氯
# 4        5          湖北澳特尔化工有限公司   复混肥料   粒状  0.1500   0.1500  0.1500   无氯
# 5        6        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2000   0.0500  0.1100   无氯
# 6        7          湖北澳特尔化工有限公司   复混肥料   粒状  0.1400   0.1600  0.1500   无氯
# 7        8        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2400   0.1000  0.1400   中氯
# 8        9        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2600   0.1000  0.1500   中氯
# 9       10        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2500   0.0500  0.0500   中氯
# 10      11        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.2000   0.0500  0.2000   无氯
# 11      12        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.3000   0.0000  0.0500   高氯
# 12      13        嘉施利（应城）化肥有限公司   复混肥料   粒状  0.3000   0.0500  0.0000   中氯
# ...

# %%
# 将data_1_1存储为result1_1.xlsx
data2_3.to_excel('E:\\泰迪\\三届\\B\\结果数据集\\result2_3.xlsx', index=False, encoding='gbk')
