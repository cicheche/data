# %%
import pandas as pd
import numpy as np
import jieba
from wordcloud import WordCloud

# %%
jqcomment = pd.read_excel('D:/泰迪杯/c题/附件1/景区评论.xlsx')
jqcomment.head(5)
# Out:
#   景区名称        评论日期                                               评论内容
# 0  A01  2020-06-16  是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十...
# 1  A01  2020-01-23  **景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看...
# 2  A01  2020-03-22  很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还...
# 3  A01  2020-12-25  有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34...
# 4  A01  2020-11-28  周五逃课跟朋友在广州集合！终于如愿以偿的到达欢乐世界。学生票198 需要出示相关证件（校卡或...

# %%
jdcomment = pd.read_excel('D:/泰迪杯/c题/附件1/酒店评论.xlsx')
jdcomment.head(5)
# Out:
#   酒店名称        评论日期                                               评论内容  入住房型
# 0  H01  2020-01-01                                          酒店很适合家庭出行  标准客房
# 1  H01  2020-01-01                                      升级了房间 延迟退房 很赞  标准客房
# 2  H01  2020-01-01  这几年，每年都会来广州，每次都会住**酒店。因为位置好，酒店的性价比也不错，这次给免费升级了...  标准客房
# 3  H01  2020-01-01                                             酒店很好不错  标准客房
# 4  H01  2020-01-01                                              超五星好评  高级客房

# %%
jqscore = pd.read_excel('D:/泰迪杯/c题/附件2/景区评分.xlsx')
jqscore.head(5)
# Out:
#   景区名称    总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 0  A01  4.390   3.8   4.9   4.9   4.5    4.5
# 1  A02  4.210   3.8   4.9   4.2   4.5    4.0
# 2  A03  4.230   3.9   4.2   4.1   4.5    4.5
# 3  A04  4.165   3.8   4.0   4.0   4.5    4.5
# 4  A05  4.240   3.9   4.9   4.0   4.5    4.2

# %%
jdscore = pd.read_excel('D:/泰迪杯/c题/附件2/酒店评分.xlsx')
jdscore.head(5)
# Out:
#    序号 酒店名称  总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 0   1  H01  4.8   4.8   4.8   4.7   4.8    4.0
# 1   2  H02  4.7   4.7   4.8   4.6   4.7    4.0
# 2   3  H03  4.8   4.8   4.8   4.8   4.9    4.0
# 3   4  H04  4.9   4.9   4.9   4.9   4.9    4.0
# 4   5  H05  4.7   4.7   4.8   4.7   4.8    4.0

# %%
jqcomment.index=jqcomment['景区名称']

# %%
url = [f'https://www.ryjiaoyu.com/tag/details/7?page={x}' for x in range(0, 20)]
    for i in url:
        get_books(i)

# %%
jqcomment
# Out:
#      景区名称        评论日期                                               评论内容
# 景区名称
# A01   A01  2020-06-16  是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十...
# A01   A01  2020-01-23  **景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看...
# A01   A01  2020-03-22  很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还...
# A01   A01  2020-12-25  有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34...
# A01   A01  2020-11-28  周五逃课跟朋友在广州集合！终于如愿以偿的到达欢乐世界。学生票198 需要出示相关证件（校卡或...
# ...   ...         ...                                                ...
# A50   A50  2015-02-25  还好吧。我们刚刚到瀑布楼遇到一点小意外，打电话到景区办公室要求帮助，景区值班领导马上行动，在...
# A50   A50  2015-02-25                               山高路远，走的很辛苦。景色宜人爬山很累。
# A50   A50  2015-02-22                           环境很好，空气非常棒，很适合全家旅游，特别是避暑
# A50   A50  2015-02-16                                都很方便，价格实惠吧，可以预早就订好。
# A50   A50  2015-02-22                        旅行社不负责任 到了景点没有与门票售票协调好 等了很久
#
# [59106 rows x 3 columns]

# %%
data1 = jqcomment['评论内容']['A01']
data1
# Out:
# A01    是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十...
# A01    **景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看...
# A01    很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还...
# A01    有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34...
# A01    周五逃课跟朋友在广州集合！终于如愿以偿的到达欢乐世界。学生票198 需要出示相关证件（校卡或...
#                              ...
# A01    我个人非常喜欢这种刺激休闲的地方 只不过放假人非常多 所以排队什么的都要很久 下次还会再去的...
# A01    很不错哦 对比了三个APP的价格什么的，最后选择了去哪儿。。棒棒哒。碰到昨天天气不冷不热 玩...
# A01                                        就是动物园不好玩 不值得去
# A01    Feb. 9 Day3：乘轻轨从珠海前往广州南（我真的不太能分清轻轨、高铁和动车），开启第二...
# A01    游**动物园周末，我和妈妈怀着兴奋的心情来到亚洲最大的**景区——**动物园游玩。一进门，我...
# Name: 评论内容, Length: 4663, dtype: object

# %%
data1.tolist()
# Out:
# ['是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十点多就到了，错过了节假日，人也还是多，不过错峰出行我们一天是把动物园逛完了，两种路线都逛完了，早上我们先坐的缆车，缆车人多，排了半小时队，小火车是把步行区转完了去坐的，到了下午四点半刚好小火车到站就下雨了，地铁站到男北门都有接驳车，很方便的，总之这次还算满意，就是有些动物表演没有看到，只看到了大象表演',
#  '**景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看人多起来就等了，进去位置很不错，所以还是早早等。拿票动物园北门拿着猫和老鼠旗帜的人就可以，他们工作人员很多，找到他们就行了。',
#  '很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还送了对应动物的小绘本，是可以带走的。不过房间大小不是很大。离动物园北门也很近，步行10分钟就能到。拿着酒店门卡或者酒店门卡里的一张小纸条进园坐缆车看4d电影这些都可以走快递通道，这一点也很方便。总的来说，性价比还是很高的。等小孩再大点还会再来的ps：楼下茶餐厅很一般，可以去酒店马路对面的餐厅吃，海鲜早茶都要比楼下的好吃很多！',
#  '有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34分钟车程就能到达园区门口，下车后就会见到写着电子取票的指引，在那就会有工作人员指引你如何取这电子票，虽然人多，但都很快就能拿到门票，公园里面的表演项目都会按照进园后的路线安排，园区是9:30开门，18:00关门，第一班的接驳车是9:45，如果你能够坐上第一班的接驳车前往园区进去游玩，按地图上的线路走，那么一日下来，都可以把所有表演的项目全看完，安排得妥妥的，我们那天是17:30左右出园区去坐接驳车回去会江地铁站，小朋友也很高兴地结束了一天的行程。',
# ...

# %%
data1 = ','.join(data1)
type(data1)
# Out:
# str

# %%
a = jieba.cut(data1)

# %%
wc=WordCloud(background_color='white',
            font_path='C:\Windows\Fonts\msyh.ttc',
            width=800,
            height=600)
wc.generate(','.join(a))
wc.to_image()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DELL\AppData\Local\Temp\jieba.cache
# Loading model cost 0.801 seconds.
# Prefix dict has been built successfully.
# <PIL.Image.Image image mode=RGB size=800x600 at 0x1D945CFB4C8>

# %%
import jieba.analyse
keywords=jieba.analyse.extract_tags(data1, topK=20, withWeight=False, allowPOS=())
print(keywords)
# Out:
# ['取票', '方便', '马戏', '好玩', '动物', '不错', '表演', '开心', '非常', '动物园', '过山车', '景区', '可以', '排队', '很多', '里面', '精彩', '值得', '火车', '小朋友']

# %%
keywords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1eb9771c7f0a> in <module>
# ----> 1 keywords
#
# NameError: name 'keywords' is not defined

# %%
data2=jqcomment.head(45891)
data2
# Out:
#      景区名称        评论日期                                               评论内容
# 景区名称
# A01   A01  2020-06-16  是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十...
# A01   A01  2020-01-23  **景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看...
# A01   A01  2020-03-22  很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还...
# A01   A01  2020-12-25  有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34...
# A01   A01  2020-11-28  周五逃课跟朋友在广州集合！终于如愿以偿的到达欢乐世界。学生票198 需要出示相关证件（校卡或...
# ...   ...         ...                                                ...
# A20   A20  2015-01-10                                  到里面需要做缆车#上去，还有很高。
# A20   A20  2015-01-05                                    景色很美，要到山顶可得早点去哦
# A20   A20  2015-01-25                                   拿票慢，景色很一般，不值这个价格
# A20   A20  2015-01-04                                           **就是一大坑。
# A20   A20  2015-01-07                      风景还行，结果爬到山背面了，爬了7个多小时！打车回正门的！
#
# [45891 rows x 3 columns]

# %%
data3 = data2['评论内容']
data3
# Out:
# 景区名称
# A01    是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十...
# A01    **景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看...
# A01    很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还...
# A01    有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34...
# A01    周五逃课跟朋友在广州集合！终于如愿以偿的到达欢乐世界。学生票198 需要出示相关证件（校卡或...
#                              ...
# A20                                    到里面需要做缆车#上去，还有很高。
# A20                                      景色很美，要到山顶可得早点去哦
# A20                                     拿票慢，景色很一般，不值这个价格
# A20                                             **就是一大坑。
# A20                        风景还行，结果爬到山背面了，爬了7个多小时！打车回正门的！
# Name: 评论内容, Length: 45891, dtype: object

# %%
data3.tolist()
# Out:
# ['是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十点多就到了，错过了节假日，人也还是多，不过错峰出行我们一天是把动物园逛完了，两种路线都逛完了，早上我们先坐的缆车，缆车人多，排了半小时队，小火车是把步行区转完了去坐的，到了下午四点半刚好小火车到站就下雨了，地铁站到男北门都有接驳车，很方便的，总之这次还算满意，就是有些动物表演没有看到，只看到了大象表演',
#  '**景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看人多起来就等了，进去位置很不错，所以还是早早等。拿票动物园北门拿着猫和老鼠旗帜的人就可以，他们工作人员很多，找到他们就行了。',
#  '很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还送了对应动物的小绘本，是可以带走的。不过房间大小不是很大。离动物园北门也很近，步行10分钟就能到。拿着酒店门卡或者酒店门卡里的一张小纸条进园坐缆车看4d电影这些都可以走快递通道，这一点也很方便。总的来说，性价比还是很高的。等小孩再大点还会再来的ps：楼下茶餐厅很一般，可以去酒店马路对面的餐厅吃，海鲜早茶都要比楼下的好吃很多！',
#  '有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34分钟车程就能到达园区门口，下车后就会见到写着电子取票的指引，在那就会有工作人员指引你如何取这电子票，虽然人多，但都很快就能拿到门票，公园里面的表演项目都会按照进园后的路线安排，园区是9:30开门，18:00关门，第一班的接驳车是9:45，如果你能够坐上第一班的接驳车前往园区进去游玩，按地图上的线路走，那么一日下来，都可以把所有表演的项目全看完，安排得妥妥的，我们那天是17:30左右出园区去坐接驳车回去会江地铁站，小朋友也很高兴地结束了一天的行程。',
# ...

# %%
data3 = ','.join(data3)
type(data3)
# Out:
# str

# %%
a = jieba.cut(data3)
type(a)
# Out:
# generator

# %%
wc=WordCloud(background_color='white',
            font_path='C:\Windows\Fonts\msyh.ttc',
            width=800,
            height=600)
wc.generate(','.join(a))
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x1D949671E88>

# %%
import jieba.analyse
keywords=jieba.analyse.extract_tags(data3, topK=50, withWeight=True, allowPOS=())
for i in keywords:
    print(i)
# Out:
# ('不错', 0.11197818302635129)
# ('取票', 0.10866478484139316)
# ('好玩', 0.07800079282146115)
# ('方便', 0.07750229369576174)
# ('表演', 0.05724230673579771)
# ('值得', 0.05357062649421889)
# ('景区', 0.04889507561867496)
# ('开心', 0.04791426692682022)
# ('可以', 0.04704326146576373)
# ('景点', 0.046140576923287845)
# ('非常', 0.04517895803407767)
# ('排队', 0.044620666023012547)
# ('很多', 0.043249948045715116)
# ('里面', 0.04322830536159583)
# ('门票', 0.036102120007093425)
# ('景色', 0.03499245081866135)
# ('游玩', 0.03402720080326278)
# ('就是', 0.03170667788364885)
# ('动物', 0.030267894356759504)
# ('风景', 0.02976974964362325)

# %%
# #NLTK分词及实现TF-IDF算法
# from nltk.text import TextCollection
# from nltk.tokenize import word_tokenize
# import nltk
# nltk.download('punkt')

# %%
x = jqcomment['评论内容'].tolist()
type(x)
# Out:
# list

# %%
x
# Out:
# ['是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十点多就到了，错过了节假日，人也还是多，不过错峰出行我们一天是把动物园逛完了，两种路线都逛完了，早上我们先坐的缆车，缆车人多，排了半小时队，小火车是把步行区转完了去坐的，到了下午四点半刚好小火车到站就下雨了，地铁站到男北门都有接驳车，很方便的，总之这次还算满意，就是有些动物表演没有看到，只看到了大象表演',
#  '**景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看人多起来就等了，进去位置很不错，所以还是早早等。拿票动物园北门拿着猫和老鼠旗帜的人就可以，他们工作人员很多，找到他们就行了。',
#  '很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还送了对应动物的小绘本，是可以带走的。不过房间大小不是很大。离动物园北门也很近，步行10分钟就能到。拿着酒店门卡或者酒店门卡里的一张小纸条进园坐缆车看4d电影这些都可以走快递通道，这一点也很方便。总的来说，性价比还是很高的。等小孩再大点还会再来的ps：楼下茶餐厅很一般，可以去酒店马路对面的餐厅吃，海鲜早茶都要比楼下的好吃很多！',
#  '有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34分钟车程就能到达园区门口，下车后就会见到写着电子取票的指引，在那就会有工作人员指引你如何取这电子票，虽然人多，但都很快就能拿到门票，公园里面的表演项目都会按照进园后的路线安排，园区是9:30开门，18:00关门，第一班的接驳车是9:45，如果你能够坐上第一班的接驳车前往园区进去游玩，按地图上的线路走，那么一日下来，都可以把所有表演的项目全看完，安排得妥妥的，我们那天是17:30左右出园区去坐接驳车回去会江地铁站，小朋友也很高兴地结束了一天的行程。',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
 
#该类会统计每个词语的tf-idf权值
tf_idf_transformer = TfidfVectorizer()

x1 = tf_idf_transformer.fit_transform(x)
type(x1)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
x1.shape
# Out:
# (59106, 209257)

# %%
jqscore.head()
# Out:
#   景区名称    总得分  服务得分  位置得分  设施得分  卫生得分  性价比得分
# 0  A01  4.390   3.8   4.9   4.9   4.5    4.5
# 1  A02  4.210   3.8   4.9   4.2   4.5    4.0
# 2  A03  4.230   3.9   4.2   4.1   4.5    4.5
# 3  A04  4.165   3.8   4.0   4.0   4.5    4.5
# 4  A05  4.240   3.9   4.9   4.0   4.5    4.2

# %%
df = jqcomment[['景区名称','评论内容']]

# %%
z1 = [f'A{x}{y}' for x in range(0,5) for y in range(0,10)][1:]
df1 = [jqcomment.loc[f'{x}']['评论内容'] for x in z1]
df1
# Out:
# [景区名称
#  A01    是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十...
#  A01    **景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看...
#  A01    很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还...
#  A01    有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34...
#  A01    周五逃课跟朋友在广州集合！终于如愿以偿的到达欢乐世界。学生票198 需要出示相关证件（校卡或...
#                               ...
#  A01    我个人非常喜欢这种刺激休闲的地方 只不过放假人非常多 所以排队什么的都要很久 下次还会再去的...
#  A01    很不错哦 对比了三个APP的价格什么的，最后选择了去哪儿。。棒棒哒。碰到昨天天气不冷不热 玩...
#  A01                                        就是动物园不好玩 不值得去
#  A01    Feb. 9 Day3：乘轻轨从珠海前往广州南（我真的不太能分清轻轨、高铁和动车），开启第二...
#  A01    游**动物园周末，我和妈妈怀着兴奋的心情来到亚洲最大的**景区——**动物园游玩。一进门，我...
#  Name: 评论内容, Length: 4663, dtype: object, 景区名称
#  A02    第一次来海洋馆，感觉好神奇啊！水母，白鲸，海豚，海豹，海象，企鹅，北极狐，北极熊，各有各的可...
#  A02                           值得一去的游玩场所，不管小孩，不同年龄玩的项目都有。
#  A02    珠海横琴**景区一日游小结：前提，是实在不想辜负长长假期，小宝每天把珠海**挂嘴边，所以就网...
#  A02    少一颗星是因为88元是抵消卷，不是管一份，里面的餐厅很多不开，我建议游客带面包进去，餐厅的东...
#  A02    比想象中的要好玩儿太多，绝对值得这个票价。几大剧场一定要去看，5D电影体验感超级强，让人身临...
# ...

# %%
len(df1)
# Out:
# 49

# %%
df2 = [jqcomment.loc['A50']['评论内容']]
df2
# Out:
# [景区名称
#  A50    **公园是广东省最大的自然保护区，是珍稀动植物宝库。公园位于**山脉的核心，在乳源瑶族自治县...
#  A50    风景是很好，唯一缺点就是景区门口验电子票窗口里面的工作人员，素质实在太差，明明订了电子票，也...
#  A50    门票八十元一张，我们刚到售票处，售票员问我们带学生证没有，学生半票，可把我乐坏了，结果看了下...
#  A50    山清水秀，空气清新，值得一游。可惜枯水期，河都露底了。工作人员的建议很实在，游小黄山时车停迎...
#  A50    **就是湖南蛮山广东一段，景色比不上湖南段，胜在地势较陡峭，但是景区开发不完善，如果晚上要赶...
#                               ...
#  A50    还好吧。我们刚刚到瀑布楼遇到一点小意外，打电话到景区办公室要求帮助，景区值班领导马上行动，在...
#  A50                                 山高路远，走的很辛苦。景色宜人爬山很累。
#  A50                             环境很好，空气非常棒，很适合全家旅游，特别是避暑
#  A50                                  都很方便，价格实惠吧，可以预早就订好。
#  A50                          旅行社不负责任 到了景点没有与门票售票协调好 等了很久
#  Name: 评论内容, Length: 236, dtype: object]

# %%
x = df1+df2
x=[str(i) for i in x]
x
# Out:
# ['景区名称\nA01    是亲子游的绝佳场所，门票就是有点贵，不过可以接受，爷爷奶奶不放心小朋友也跟上来了，当天我们十...\nA01    **景区差不多，票价偏贵了。大马戏比较精彩，八点的场次，6点40才能检票进入，我们6点多看看...\nA01    很有**特色的亲子酒店，房间里的装修很可爱，小孩子特别喜欢，洗漱用品也很有特色，对应的房间还...\nA01    有园区的工作人员在那，他会主动给你园区里的地图和表演的时间安排，很周到，上接驳车大概也是34...\nA01    周五逃课跟朋友在广州集合！终于如愿以偿的到达欢乐世界。学生票198 需要出示相关证件（校卡或...\n                             ...                        \nA01    我个人非常喜欢这种刺激休闲的地方 只不过放假人非常多 所以排队什么的都要很久 下次还会再去的...\nA01    很不错哦 对比了三个APP的价格什么的，最后选择了去哪儿。。棒棒哒。碰到昨天天气不冷不热 玩...\nA01                                        就是动物园不好玩 不值得去\nA01    Feb. 9 Day3：乘轻轨从珠海前往广州南（我真的不太能分清轻轨、高铁和动车），开启第二...\nA01    游**动物园周末，我和妈妈怀着兴奋的心情来到亚洲最大的**景区——**动物园游玩。一进门，我...\nName: 评论内容, Length: 4663, dtype: object',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
 
#该类会统计每个词语的tf-idf权值
tf_idf_transformer = TfidfVectorizer()

x1 = tf_idf_transformer.fit_transform(x)
type(x1)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
x1.shape
# Out:
# (50, 1986)

# %%
y = jqscore

# %%
y1 = np.array(y)

# %%
y1 = y.drop(['景区名称'],axis=1)

# %%
y1 = y1.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-bbc999db9eec> in <module>
# ----> 1 y1 = y1.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
type(y1[2][3])
# Out:
# numpy.float64

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier as GBDT
from sklearn.ensemble import ExtraTreesClassifier as ET
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.ensemble import AdaBoostClassifier as ADA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import numpy as np
X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size=0.5)

# %%
### 第一层模型
clfs = [ GBDT(n_estimators=100),
       RF(n_estimators=100),
       ET(n_estimators=100),
       ADA(n_estimators=100)
]
X_train_stack  = np.zeros((X_train.shape[0], len(clfs)))
X_test_stack = np.zeros((X_test.shape[0], len(clfs)))

# %%
### 6折stacking
n_folds = 6
skf = StratifiedKFold(n_splits=n_folds, random_state=1986)
for i,clf in enumerate(clfs):
#     print("分类器：{}".format(clf))
    X_stack_test_n = np.zeros((X_test.shape[0], n_folds))
    for j,(train_index,test_index) in enumerate(skf.split(X_train,y_train)):
                tr_x = X_train[train_index]
                tr_y = y_train[train_index]
                clf.fit(tr_x, tr_y)
                #生成stacking训练数据集
                X_train_stack [test_index, i] = clf.predict_proba(X_train[test_index])[:,1]
                X_stack_test_n[:,j] = clf.predict_proba(X_test)[:,1]
    #生成stacking测试数据集
    X_test_stack[:,i] = X_stack_test_n.mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-9168c218a127> in <module>
#       5 #     print("分类器：{}".format(clf))
#       6     X_stack_test_n = np.zeros((X_test.shape[0], n_folds))
# ----> 7     for j,(train_index,test_index) in enumerate(skf.split(X_train,y_train)):
#       8                 tr_x = X_train[train_index]
#       9                 tr_y = y_train[train_index]
#
# D:\Anacnda\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#     333                 .format(self.n_splits, n_samples))
#     334
# --> 335         for train, test in super().split(X, y, groups):
#     336             yield train, test
#     337
#
# D:\Anacnda\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#      87         X, y, groups = indexable(X, y, groups)
#      88         indices = np.arange(_num_samples(X))
# ...

# %%
type(y_train)
# Out:
# numpy.ndarray
